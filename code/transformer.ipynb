# %% [markdown]
# ### RMS 计算
# $$ \text{RMS}(x) = \sqrt{\frac{1}{d} \sum_{i=1}^{d} x_i^2 + \epsilon} $$
#
# ### 归一化与缩放
# $$ y_i = \gamma_i \frac{x_i}{\text{RMS}(x)} $$

# %%
import torch 
import torch.nn as nn

class RMSNorm(nn.Module):
    def __init__(self , dim: int , eps:float = 1e-6):
    
    def __norm(self , x:torch.Tensor):

    def forward(self , x:torch.Tensor):

# %% [markdown]
# #### Positional Encoder
# $$
# \begin{cases}
# PE_{(pos, 2i)} = \sin\left(\frac{pos}{10000^{2i / d_{model}}}\right) \\
# PE_{(pos, 2i+1)} = \cos\left(\frac{pos}{10000^{2i / d_{model}}}\right)
# \end{cases}
# $$

# %%
import torch 
import torch.nn as nn
import math

class PostionalEncoder(nn.Module):
    def __init__(self , dim:int , max_len:int):
        

    def forward(self , x:torch.Tensor):
        

PE = PostionalEncoder(512,3)
input = torch.rand(3,2,512)
output = PE(input)
print(output.shape)
print(output)
# Out:
# torch.Size([3, 2, 512])
# tensor([[[0.3481, 1.9074, 0.2144,  ..., 1.4093, 0.8294, 1.4816],
#          [1.3099, 1.1977, 0.9235,  ..., 1.2687, 0.5718, 1.5639]],
#
#         [[0.6613, 1.4538, 0.8063,  ..., 1.2249, 0.1435, 1.5878],
#          [1.5750, 1.1481, 1.4740,  ..., 1.6876, 0.0093, 1.0526]],
#
#         [[0.7308, 1.0580, 0.8606,  ..., 1.9325, 0.5200, 1.6412],
#          [1.7513, 0.9429, 1.6418,  ..., 1.0097, 0.9921, 1.0692]]])
